# %%
from supabase import create_client, Client
import pandas as pd

# Thông tin Supabase
url = "https://xnrkdgmepilckxrdndzi.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InhucmtkZ21lcGlsY2t4cmRuZHppIiwicm9sZSI6ImFub24iLCJpYXQiOjE3Njg1NTUxMTcsImV4cCI6MjA4NDEzMTExN30.9srbJMGw1dPxXnDZkPzAXiwP_-y2zaX3wSJ0mkZLfA0"

# Kết nối
supabase: Client = create_client(url, key)

# Lấy toàn bộ dữ liệu từ bảng
response = supabase.table("data").select("*").execute()

# Dữ liệu trả về
data = response.data
# Chuyển đổi dữ liệu thành DataFrame của pandas

df = pd.DataFrame(data)
print(df.head(1))
# Out:
#                                      id  \
# 0  8e09bd8a-17a9-4b27-98a3-9b8075b201f7
#
#                                      attraction_name         name  \
# 0  Top 25 quán ăn ngon Đà Nẵng bạn không nên bỏ l...  Bún Mắm Vân
#
#                                           address category  \
# 0  23/14 Trần Kế Xương, phường Hải Châu, Đà Nẵng.  Ẩm thực
#
#                                           source_url  \
# 0  https://www.ivivu.com/blog/2012/10/20-quan-an-...
#
#                                            specialty      area  \
# 0  Bún mắm (thịt heo quay, đậu rang, rau, nước xố...  Hải Châu
#
#                          created_at
# 0  2026-01-23T11:42:02.849424+00:00

# %%
df.to_csv("db.csv", index=False, encoding="utf-8-sig")

print("✅ Đã lưu dữ liệu vào db.csv")
